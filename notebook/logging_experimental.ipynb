# %%
print("all ok")
# Out:
# all ok

# %%
import logging
import os
from datetime import datetime


def log_current_time():
    logging.info(f"Current time: {datetime.now()}")

logs_dir = os.path.join(os.getcwd(), "logs")
logs_dir

if not os.path.exists(logs_dir):
    os.makedirs(logs_dir, exist_ok=True)
    logging.info(f"Created logs directory at {logs_dir}")
# Out:
# INFO:root:Created logs directory at /home/jayant/KrishAcademy/Module1/document_portal/notebook/logs

# %%
LOG_FILE_NAME = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
LOG_FILE_NAME

LOG_FILE = os.path.join(logs_dir, LOG_FILE_NAME)
LOG_FILE
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE_NAME)
LOG_FILE_PATH
# Out:
# '/home/jayant/KrishAcademy/Module1/document_portal/notebook/logs/09_01_2025_21_43_31.log'

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

# %%
logger=logging.getLogger("DocumentPortal")
logger.info("Logging is set up.")
# Out:
# INFO:DocumentPortal:Logging is set up.

# %%
import structlog
log=structlog.get_logger()

# %%
log.info("User uploaded a file", user_id=123, filename="report.pdf")
# Out:
# 2025-09-01 21:47:31 [info     ] User uploaded a file           filename=report.pdf user_id=123

# %%
log.error("Failed to process PDF", error="File not found", user_id=123)
# Out:
# 2025-09-01 21:48:55 [error    ] Failed to process PDF          error='File not found' user_id=123
